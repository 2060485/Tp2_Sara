# %% [markdown]
# <a href="https://colab.research.google.com/github/2060485/Tp2_Sara/blob/main/TP2_420_514.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **420-514 - Travail Pratique 2**
#
# ## **Informations de l'étudiant :**
# ### Nom : Normand
# ### Prenom : Mathis
# ### Numero DA : 2060485
# ### Session : A24

# %% [markdown]
# ## **Instructions**
#
# * Faites le travail individuellement.
# * La remise du code se fait Léa avant la date limite indiquée dans la boite de remise.
# * La présentation du code est évaluée.
#
# ## **Contexte**
#
# Vous travaillez pour une entreprise qui s'intéresse à la performance des entreprises dans plusieurs secteurs et veut mieux comprendre la répartition des entreprises, leur croissance, et les tendances globales du marché. Vous utiliserez la base de données MongoDB **`sample_training`**, qui contient plusieurs collections, notamment **`companies`**, **`grades`**, **`inspections`**, et **`zips`**. Ces collections regroupent des informations sur des entreprises, des inspections, des performances académiques et des données géographiques.
#
# L'objectif de ce projet est de récupérer des informations sur une entreprise à partir d'une base de données MongoDB. Le travail se déroule en trois étapes principales :
#
# 1. Extraction des données à partir de MongoDB.
# 2. Transformation des données pour obtenir les informations pertinentes à partir de contrôles dynamiques de sélection.
# 3. Affichage des résultats sous forme de graphiques et de visualisations.

# %% [markdown]
# ### **Étape 1 : Extraction des données**
# #### **Connexion à la base de donnée MongoDB**
#
# Il faut charger la base de données MongoDB dans un cluster créé avec votre compte _Atlas_. Les informations de connection sont comme les suivantes:
#
# * user : 420-514_A24
# * password : Str0ng_P@ssw0rd_420-514
# * database : sample_training
# * host : tp.ek83z.mongodb.net
# * collections : companies, grades, inspections et zips
#
# Vous devez vous connecter à la base de données, importer et fusionnez les informations des tables dans un Dataframe de pandas.

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.1 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 12.0 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://420-514_A24:Str0ng_P%40ssw0rd_420-514@tp.ek83z.mongodb.net/?retryWrites=true&w=majority&appName=Tp"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
    db = client.sample_training
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# #### Tâche 1.1 : Exploration des données
# - Utilisez la collection **`companies`** pour obtenir un aperçu général des données disponibles. Affichez les 10 premiers documents.
#   - **MongoDB exemple de requête** :
#     ```python
#     db.companies.find().limit(10)
#     ```
#   - Décrivez brièvement la structure des documents (champs et types de données).

# %%
for company in db.companies.find().limit(10):
    print(company);
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297da2'), 'name': 'Cisco', 'permalink': 'cisco', 'crunchbase_url': 'http://www.crunchbase.com/company/cisco', 'homepage_url': 'http://www.cisco.com', 'blog_url': 'http://blogs.cisco.com', 'blog_feed_url': '', 'twitter_username': 'CiscoSystems', 'category_code': 'network_hosting', 'number_of_employees': 63000, 'founded_year': 1984, 'founded_month': None, 'founded_day': None, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': '', 'tag_list': 'networking', 'alias_list': '', 'email_address': '', 'phone_number': '(408) 526-4000', 'description': '', 'created_at': 'Sat Jun 09 14:33:35 UTC 2007', 'updated_at': 'Fri Dec 13 03:59:09 UTC 2013', 'overview': '<p>Cisco designs and sells hardware, software, networking, and communications technology services.  Products are distributed under five brands, namely Cisco, Linksys, WebEx, IronPort, and Scientific Atlanta.</p>\n\n<p>Cisco was founded in 1984 by a small group of computer scientists from Stanford University. Since the company&#8217;s inception, Cisco engineers have been leaders in the development of Internet Protocol (IP)-based networking technologies.</p>\n\n<p>Cisco name is based on its origins starting up in San Francisco. </p>', 'image': {'available_sizes': [[[110, 73], 'assets/images/resized/0001/8309/18309v6-max-150x150.png'], [[110, 73], 'assets/images/resized/0001/8309/18309v6-max-250x250.png'], [[110, 73], 'assets/images/resized/0001/8309/18309v6-max-450x450.png']], 'attribution': None}, 'products': [], 'relationships': [{'is_past': False, 'title': 'SVP, Office of the Chairman & CEO', 'person': {'first_name': 'Donald', 'last_name': 'R. Proctor', 'permalink': 'donald-r-proctor'}}, {'is_past': False, 'title': 'SVP, Office of the Chairman & CEO', 'person': {'first_name': 'Carlos', 'last_name': 'Dominguez', 'permalink': 'carlos-dominguez'}}, {'is_past': False, 'title': 'SVP, Office of the Chairman & CEO', 'person': {'first_name': 'Howard', 'last_name': 'Charney', 'permalink': 'howard-charney'}}, {'is_past': False, 'title': 'Chairman & CEO, Cisco Greater China', 'person': {'first_name': 'Owen', 'last_name': 'Chan', 'permalink': 'owen-chan'}}, {'is_past': False, 'title': 'CEO & Chairman', 'person': {'first_name': 'John', 'last_name': 'T. Chambers', 'permalink': 'john-t-chambers'}}, {'is_past': False, 'title': 'Executive Vice President and Chief Development Officer', 'person': {'first_name': 'Charles', 'last_name': 'Giancarlo', 'permalink': 'charles-giancarlo'}}, {'is_past': False, 'title': 'SVP, Chief Security Officer, Threat Response Intelligence & Development', 'person': {'first_name': 'John', 'last_name': 'N. Stewart', 'permalink': 'john-n-stewart'}}, {'is_past': False, 'title': 'SVP, CTO Strategy Group', 'person': {'first_name': 'Barry', 'last_name': "O'Sullivan", 'permalink': 'barry-osullivan'}}, {'is_past': False, 'title': 'President, Smart+Connected Communities & Cisco Deputy Chief Globalisation Officer', 'person': {'first_name': 'Anil', 'last_name': 'Menon', 'permalink': 'anil-menon'}}, {'is_past': False, 'title': 'CTO, Wireless Networking Business Unit Network Services Technology Group', 'person': {'first_name': 'Bob', 'last_name': 'Friday', 'permalink': 'bob-friday'}}, {'is_past': False, 'title': 'SVP & Chief Human Resources Officer', 'person': {'first_name': 'Kathleen', 'last_name': 'Weslock', 'permalink': 'kathleen-weslock'}}, {'is_past': False, 'title': 'EVP & Chief Development Officer', 'person': {'first_name': 'Pankaj', 'last_name': 'Patel', 'permalink': 'pankaj-patel'}}, {'is_past': False, 'title': 'President & COO', 'person': {'first_name': 'Gary', 'last_name': 'Moore', 'permalink': 'gary-moore'}}, {'is_past': False, 'title': 'EVP, Industry Solutions & Chief Globalisation Officer', 'person': {'first_name': 'Wim', 'last_name': 'Elfrink', 'permalink': 'wim-elfrink'}}, {'is_past': False, 'title': 'EVP & CFO', 'person': {'first_name': 'Frank', 'last_name': 'Calderoni', 'permalink': 'frank-cal ...
# {'_id': ObjectId('52cdef7c4bab8bd675297d8a'), 'name': 'Wetpaint', 'permalink': 'abc2', 'crunchbase_url': 'http://www.crunchbase.com/company/wetpaint', 'homepage_url': 'http://wetpaint-inc.com', 'blog_url': 'http://digitalquarters.net/', 'blog_feed_url': 'http://digitalquarters.net/feed/', 'twitter_username': 'BachelrWetpaint', 'category_code': 'web', 'number_of_employees': 47, 'founded_year': 2005, 'founded_month': 10, 'founded_day': 17, 'deadpooled_year': 1, 'tag_list': 'wiki, seattle, elowitz, media-industry, media-platform, social-distribution-system', 'alias_list': '', 'email_address': 'info@wetpaint.com', 'phone_number': '206.859.6300', 'description': 'Technology Platform Company', 'created_at': datetime.datetime(2007, 5, 25, 6, 51, 27), 'updated_at': 'Sun Dec 08 07:15:44 UTC 2013', 'overview': '<p>Wetpaint is a technology platform company that uses its proprietary state-of-the-art technology and expertise in social media to build and monetize audiences for digital publishers. Wetpaint’s own online property, Wetpaint Entertainment, an entertainment news site that attracts more than 12 million unique visitors monthly and has over 2 million Facebook fans, is a proof point to the company’s success in building and engaging audiences. Media companies can license Wetpaint’s platform which includes a dynamic playbook tailored to their individual needs and comprehensive training. Founded by Internet pioneer Ben Elowitz, and with offices in New York and Seattle, Wetpaint is backed by Accel Partners, the investors behind Facebook.</p>', 'image': {'available_sizes': [[[150, 75], 'assets/images/resized/0000/3604/3604v14-max-150x150.jpg'], [[250, 125], 'assets/images/resized/0000/3604/3604v14-max-250x250.jpg'], [[450, 225], 'assets/images/resized/0000/3604/3604v14-max-450x450.jpg']]}, 'products': [{'name': 'Wikison Wetpaint', 'permalink': 'wetpaint-wiki'}, {'name': 'Wetpaint Social Distribution System', 'permalink': 'wetpaint-social-distribution-system'}], 'relationships': [{'is_past': False, 'title': 'Co-Founder and VP, Social and Audience Development', 'person': {'first_name': 'Michael', 'last_name': 'Howell', 'permalink': 'michael-howell'}}, {'is_past': False, 'title': 'Co-Founder/CEO/Board of Directors', 'person': {'first_name': 'Ben', 'last_name': 'Elowitz', 'permalink': 'ben-elowitz'}}, {'is_past': False, 'title': 'COO/Board of Directors', 'person': {'first_name': 'Rob', 'last_name': 'Grady', 'permalink': 'rob-grady'}}, {'is_past': False, 'title': 'SVP, Strategy and Business Development', 'person': {'first_name': 'Chris', 'last_name': 'Kollas', 'permalink': 'chris-kollas'}}, {'is_past': False, 'title': 'Board', 'person': {'first_name': 'Theresia', 'last_name': 'Ranzetta', 'permalink': 'theresia-ranzetta'}}, {'is_past': False, 'title': 'Board Member', 'person': {'first_name': 'Gus', 'last_name': 'Tai', 'permalink': 'gus-tai'}}, {'is_past': False, 'title': 'Board', 'person': {'first_name': 'Len', 'last_name': 'Jordan', 'permalink': 'len-jordan'}}, {'is_past': False, 'title': 'Head of Technology and Product', 'person': {'first_name': 'Alex', 'last_name': 'Weinstein', 'permalink': 'alex-weinstein'}}, {'is_past': True, 'title': 'CFO', 'person': {'first_name': 'Bert', 'last_name': 'Hogue', 'permalink': 'bert-hogue'}}, {'is_past': True, 'title': 'CFO/ CRO', 'person': {'first_name': 'Brian', 'last_name': 'Watkins', 'permalink': 'brian-watkins'}}, {'is_past': True, 'title': 'Senior Vice President, Marketing', 'person': {'first_name': 'Rob', 'last_name': 'Grady', 'permalink': 'rob-grady'}}, {'is_past': True, 'title': 'VP, Technology and Product', 'person': {'first_name': 'Werner', 'last_name': 'Koepf', 'permalink': 'werner-koepf'}}, {'is_past': True, 'title': 'VP Marketing', 'person': {'first_name': 'Kevin', 'last_name': 'Flaherty', 'permalink': 'kevin-flaherty'}}, {'is_past': True, 'title': 'VP User Experience', 'person': {'first_name': 'Alex', 'last_name': 'Berg', 'permalink': 'alex-berg'}}, {'is_past': True, 'title': 'VP Engineering',  ...
# {'_id': ObjectId('52cdef7c4bab8bd675297d95'), 'name': 'StumbleUpon', 'permalink': 'stumbleupon', 'crunchbase_url': 'http://www.crunchbase.com/company/stumbleupon', 'homepage_url': 'http://www.stumbleupon.com', 'blog_url': 'http://www.stumbleupon.com/blog', 'blog_feed_url': '', 'twitter_username': 'stumbleupon', 'category_code': 'web', 'number_of_employees': None, 'founded_year': 2002, 'founded_month': 2, 'founded_day': 1, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'content-discovery, find, content, stumble, toolbar', 'alias_list': '', 'email_address': '', 'phone_number': '', 'description': 'Content discovery service', 'created_at': datetime.datetime(2007, 6, 1, 9, 28, 13), 'updated_at': 'Wed Mar 20 04:14:12 UTC 2013', 'overview': '<p>StumbleUpon is the easiest way to discover new and interesting things from across the Web. More than 25 million people turn to StumbleUpon to be informed, entertained and surprised by content and information recommended just for them. In addition, more than 80,000 brands, publishers and other marketers have used StumbleUpon’s Paid Discovery platform to tell their stories and promote their products and services. Explore more at www.stumbleupon.com.</p>', 'image': {'available_sizes': [[[150, 38], 'assets/images/resized/0004/1614/41614v6-max-150x150.png'], [[250, 64], 'assets/images/resized/0004/1614/41614v6-max-250x250.png'], [[302, 78], 'assets/images/resized/0004/1614/41614v6-max-450x450.png']], 'attribution': None}, 'products': [], 'relationships': [{'is_past': False, 'title': 'Co-Founder/CTO', 'person': {'first_name': 'Geoff', 'last_name': 'Smith', 'permalink': 'geoff-smith-3'}}, {'is_past': False, 'title': 'Co-Founder & Chairman', 'person': {'first_name': 'Garrett', 'last_name': 'Camp', 'permalink': 'garrett-camp'}}, {'is_past': False, 'title': 'CEO', 'person': {'first_name': 'Mark', 'last_name': 'Bartels', 'permalink': 'mark-bartels'}}, {'is_past': False, 'title': 'VP Product', 'person': {'first_name': 'David', 'last_name': 'Marks', 'permalink': 'david-marks'}}, {'is_past': False, 'title': 'Vice President of Sales', 'person': {'first_name': 'Teal', 'last_name': 'Newland', 'permalink': 'teal-newland'}}, {'is_past': False, 'title': 'Board of Directors', 'person': {'first_name': 'David', 'last_name': 'Hornik', 'permalink': 'david-hornik'}}, {'is_past': False, 'title': 'Advisor', 'person': {'first_name': 'Josh', 'last_name': 'Spear', 'permalink': 'josh-spear'}}, {'is_past': False, 'title': 'Advisor', 'person': {'first_name': 'Timothy', 'last_name': 'Ferriss', 'permalink': 'tim-ferriss'}}, {'is_past': False, 'title': 'Member, Board of Advisors', 'person': {'first_name': 'Bob', 'last_name': 'Bahramipour', 'permalink': 'bob-bahramipour'}}, {'is_past': False, 'title': 'Advisory Board Member', 'person': {'first_name': 'Steve', 'last_name': 'Jang', 'permalink': 'steve-jang'}}, {'is_past': False, 'title': 'Board of Directors', 'person': {'first_name': 'Ram', 'last_name': 'Shriram', 'permalink': 'ram-shriram'}}, {'is_past': False, 'title': 'Legal Counsel', 'person': {'first_name': 'Dina', 'last_name': 'Hellerstein', 'permalink': 'dina-hellerstein'}}, {'is_past': False, 'title': 'Revenue & Sales Analytics Manager', 'person': {'first_name': 'Stephen', 'last_name': 'Cheung', 'permalink': 'stephen-cheung'}}, {'is_past': True, 'title': 'CEO, co-founder', 'person': {'first_name': 'Garrett', 'last_name': 'Camp', 'permalink': 'garrett-camp'}}, {'is_past': True, 'title': 'Chief Product Officer', 'person': {'first_name': 'Cody', 'last_name': 'Simms', 'permalink': 'cody-simms'}}, {'is_past': True, 'title': 'VP', 'person': {'first_name': 'Marc', 'last_name': 'Leibowitz', 'permalink': 'marc-leibowitz'}}, {'is_past': True, 'title': 'VP, Marketing & Business Operations', 'person': {'first_name': 'David', 'last_name': 'Feller', 'permalink': 'david-feller'}}, {'is_past': True, 'title': 'Businessman', 'person': {'first_name': 'David', 'last_name': 'Lee', ' ...
# {'_id': ObjectId('52cdef7c4bab8bd675297d94'), 'name': 'Twitter', 'permalink': 'twitter', 'crunchbase_url': 'http://www.crunchbase.com/company/twitter', 'homepage_url': 'http://twitter.com', 'blog_url': 'http://twitter.com/blog', 'blog_feed_url': 'http://feeds.feedburner.com/TwitterBlog', 'twitter_username': 'twitter', 'category_code': 'social', 'number_of_employees': 1300, 'founded_year': 2006, 'founded_month': 3, 'founded_day': 21, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': '', 'tag_list': 'text, messaging, social, community, twitter, tweet, twttr, microblog, sms', 'alias_list': '', 'email_address': 'press@twitter.com', 'phone_number': '', 'description': 'Real time communication platform', 'created_at': 'Fri Jun 01 08:42:34 UTC 2007', 'updated_at': 'Sat Dec 07 16:07:56 UTC 2013', 'overview': '<p>Created in 2006, Twitter is a global real-time communications platform with 400 million monthly visitors to twitter.com, more than 200 million monthly active users around the world.</p>\n\n<p>We see a billion tweets every 2.5 days on every conceivable topic. World leaders, major athletes, star performers, news organizations and entertainment outlets are among the millions of active Twitter accounts through which users can truly get the pulse of the planet.</p>', 'image': {'available_sizes': [[[150, 150], 'assets/images/resized/0000/2755/2755v33-max-150x150.png'], [[250, 250], 'assets/images/resized/0000/2755/2755v33-max-250x250.png'], [[300, 300], 'assets/images/resized/0000/2755/2755v33-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'Twitter Blocks', 'permalink': 'twitter-blocks'}, {'name': 'Twicco', 'permalink': 'twicco'}], 'relationships': [{'is_past': False, 'title': 'CEO', 'person': {'first_name': 'Dick', 'last_name': 'Costolo', 'permalink': 'dick-costolo'}}, {'is_past': False, 'title': 'Co-Founder', 'person': {'first_name': 'Evan', 'last_name': 'Williams', 'permalink': 'evan-williams'}}, {'is_past': False, 'title': 'Co-Founder, Exec Chairman', 'person': {'first_name': 'Jack', 'last_name': 'Dorsey', 'permalink': 'jack-dorsey'}}, {'is_past': False, 'title': 'Co-founder', 'person': {'first_name': 'Biz', 'last_name': 'Stone', 'permalink': 'biz-stone'}}, {'is_past': False, 'title': 'CTO', 'person': {'first_name': 'Adam', 'last_name': 'Messinger', 'permalink': 'adam-messinger'}}, {'is_past': False, 'title': 'COO', 'person': {'first_name': 'Ali', 'last_name': 'Rowghani', 'permalink': 'ali-rowghani'}}, {'is_past': False, 'title': 'VP, Marketing and Communications', 'person': {'first_name': 'Gabriel', 'last_name': 'Stricker', 'permalink': 'gabriel-stricker'}}, {'is_past': False, 'title': 'VP of Product', 'person': {'first_name': 'Michael', 'last_name': 'Sippey', 'permalink': 'michael-sippey'}}, {'is_past': False, 'title': 'Vice President, Design', 'person': {'first_name': 'Mike', 'last_name': 'Davidson', 'permalink': 'mike-davidson'}}, {'is_past': False, 'title': 'VP, Engineering', 'person': {'first_name': 'Alex', 'last_name': 'Roetter', 'permalink': 'alex-roetter'}}, {'is_past': False, 'title': 'SVP Engineering', 'person': {'first_name': 'Chris', 'last_name': 'Fry', 'permalink': 'chris-fry'}}, {'is_past': False, 'title': 'VP of Product for Revenue', 'person': {'first_name': 'Kevin', 'last_name': 'Weil', 'permalink': 'kevin-weil'}}, {'is_past': False, 'title': 'Vice President of Infrastructure Operation engineering', 'person': {'first_name': 'Mazen', 'last_name': 'Rawashdeh', 'permalink': 'mazen-rawashdeh'}}, {'is_past': False, 'title': 'Vice President, Business Development', 'person': {'first_name': 'Jana', 'last_name': 'Messerschmidt', 'permalink': 'jana-messerschmidt'}}, {'is_past': False, 'title': 'VP of Platform Engineering', 'person': {'first_name': 'Raffi', 'last_name': 'Krikorian', 'permalink': 'raffi-krikorian'}}, {'is_past': False, 'title': 'Distributed Systems Architect', 'person': {'first_name': 'John', 'last_name': 'Kalucki', 'permalink': 'john-kalucki'}}, {' ...
# {'_id': ObjectId('52cdef7c4bab8bd675297d97'), 'name': 'Scribd', 'permalink': 'scribd', 'crunchbase_url': 'http://www.crunchbase.com/company/scribd', 'homepage_url': 'http://scribd.com', 'blog_url': 'http://blog.scribd.com/', 'blog_feed_url': 'http://blog.scribd.com/feed/', 'twitter_username': 'scribd', 'category_code': 'news', 'number_of_employees': 50, 'founded_year': 2007, 'founded_month': None, 'founded_day': None, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'book-subscription, digital-library, netflix-for-books, sharing, documents, social, pdf, social-publishing, online-publishing', 'alias_list': '', 'email_address': 'feedback@scribd.com', 'phone_number': '', 'description': 'Read Unlimited Books', 'created_at': 'Sat Jun 02 07:34:05 UTC 2007', 'updated_at': 'Sat Dec 14 00:46:12 UTC 2013', 'overview': '<p>Scribd is the world’s biggest digital library, featuring a subscription service with premier ebooks including New York Times bestsellers and literary classics. A pioneer of the all-you-can-read model, Scribd&#8217;s subscriptions service allows readers to have unlimited access to more than 100,000 books from over 900 publishers, including Harper Collins, Rosetta, and Workman.</p>\n\n<p>Launched in 2007 by Trip Adler and Jared Friedman in San Francisco, CA, Scribd is backed by Y Combinator, Charles River Ventures, and Redpoint Ventures. Scribd&#8217; has more than 80 million active readers visiting the site each month, and its document reader has been embedded more than 10 million times across the web on sites like The New York Times, USA Today, Guardian, and TechCrunch. </p>', 'image': {'available_sizes': [[[114, 114], 'assets/images/resized/0000/3184/3184v25-max-150x150.png'], [[114, 114], 'assets/images/resized/0000/3184/3184v25-max-250x250.png'], [[114, 114], 'assets/images/resized/0000/3184/3184v25-max-450x450.png']], 'attribution': None}, 'products': [], 'relationships': [{'is_past': False, 'title': 'CEO/Co-Founder', 'person': {'first_name': 'Trip', 'last_name': 'Adler', 'permalink': 'john-adler'}}, {'is_past': False, 'title': 'CMO', 'person': {'first_name': 'Julie', 'last_name': 'Haddon', 'permalink': 'julie-haddon'}}, {'is_past': False, 'title': 'CTO/Co-Founder', 'person': {'first_name': 'Jared', 'last_name': 'Friedman', 'permalink': 'jared-friedman'}}, {'is_past': False, 'title': 'VP, Content Acquisition', 'person': {'first_name': 'Andrew', 'last_name': 'Weinstein', 'permalink': 'andrew-weinstein'}}, {'is_past': False, 'title': 'Board of Directors', 'person': {'first_name': 'Bill', 'last_name': 'Tai', 'permalink': 'bill-tai'}}, {'is_past': False, 'title': 'Board of Directors', 'person': {'first_name': 'David', 'last_name': 'Sacks', 'permalink': 'david-sacks'}}, {'is_past': False, 'title': 'VP, Engineering', 'person': {'first_name': 'Sabeen', 'last_name': 'Minns', 'permalink': 'sabeen-minns'}}, {'is_past': False, 'title': 'Board of Directors', 'person': {'first_name': 'Geoff', 'last_name': 'Yang', 'permalink': 'geoff-yang'}}, {'is_past': False, 'title': 'Investor', 'person': {'first_name': 'Lou', 'last_name': 'Kerner', 'permalink': 'lou-kerner'}}, {'is_past': True, 'title': 'COO/Co-Founder', 'person': {'first_name': 'Tikhon', 'last_name': 'Bernstam', 'permalink': 'tikhon-bernstam'}}, {'is_past': True, 'title': 'VP, Business Development', 'person': {'first_name': 'Mike', 'last_name': 'McGuinness', 'permalink': 'mike-mcguinness'}}, {'is_past': True, 'title': 'SVP, Business Development', 'person': {'first_name': 'Rob', 'last_name': 'Macdonald', 'permalink': 'rob-macdonald'}}, {'is_past': True, 'title': 'President', 'person': {'first_name': 'George', 'last_name': 'Consagra', 'permalink': 'george-consagra'}}, {'is_past': True, 'title': 'Developer', 'person': {'first_name': 'Quin', 'last_name': 'Hoxie', 'permalink': 'quin-hoxie'}}, {'is_past': True, 'title': 'Community & Content Manager', 'person': {'first_name': 'Mariko', 'last_name': 'Fritz-Krockow', 'per ...
# {'_id': ObjectId('52cdef7c4bab8bd675297da5'), 'name': 'Technorati', 'permalink': 'technorati', 'crunchbase_url': 'http://www.crunchbase.com/company/technorati', 'homepage_url': 'http://technoratimedia.com', 'blog_url': 'http://technoratimedia.com/tm-blog/', 'blog_feed_url': '', 'twitter_username': 'technorati', 'category_code': 'advertising', 'number_of_employees': 35, 'founded_year': 2002, 'founded_month': 6, 'founded_day': 1, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'blogs, search', 'alias_list': '', 'email_address': '', 'phone_number': '415-896-3000', 'description': 'Advertising platform/Publisher network', 'created_at': 'Tue Jun 12 04:06:06 UTC 2007', 'updated_at': 'Tue Nov 12 07:23:57 UTC 2013', 'overview': '<p>Technorati Media is an advertising platform that connects brands and audiences using technology and real-time market insights to optimize digital advertising interactions across an expanding high-quality publisher network. Since launching in 2008, the Technorati Media platform has quickly grown into one of the largest social ad platforms (over 1,900 independent sites, blogs, and social networks), boasting an audience of over 123.5 million US unique visitors per month.</p>\n\n<p>The Technorati Media advertising platform also offers publisher services, maximizing fill and yield through personal service, granular visibility, and custom opportunities with top-tier brands.</p>', 'image': {'available_sizes': [[[150, 35], 'assets/images/resized/0001/0740/10740v1-max-150x150.png'], [[250, 59], 'assets/images/resized/0001/0740/10740v1-max-250x250.png'], [[379, 90], 'assets/images/resized/0001/0740/10740v1-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'Technorati', 'permalink': 'technorati'}, {'name': 'Popular', 'permalink': 'popular'}, {'name': 'WTF', 'permalink': 'wtf'}], 'relationships': [{'is_past': False, 'title': 'Chairman', 'person': {'first_name': 'Dave', 'last_name': 'Sifry', 'permalink': 'dave-sifry'}}, {'is_past': False, 'title': 'CTO', 'person': {'first_name': 'Abderrezak', 'last_name': 'Kamel', 'permalink': 'abderrezak-kame'}}, {'is_past': False, 'title': 'CEO', 'person': {'first_name': 'Shani', 'last_name': 'Higgins', 'permalink': 'shani-higgins'}}, {'is_past': False, 'title': 'Board', 'person': {'first_name': 'Andreas', 'last_name': 'Stavropoulos', 'permalink': 'andreas-stavropoulos'}}, {'is_past': False, 'title': 'Board Member', 'person': {'first_name': 'Steve', 'last_name': 'Katinsky', 'permalink': 'steve-katinsky'}}, {'is_past': False, 'title': 'Board Member', 'person': {'first_name': 'Ryan', 'last_name': 'McIntyre', 'permalink': 'ryan-mcintyre'}}, {'is_past': False, 'title': 'Publisher', 'person': {'first_name': 'John', 'last_name': 'Swartz', 'permalink': 'john-swartz'}}, {'is_past': True, 'title': 'Founder', 'person': {'first_name': 'Dave', 'last_name': 'Sifry', 'permalink': 'dave-sifry'}}, {'is_past': True, 'title': 'Executive Chairman, Board of Directors', 'person': {'first_name': 'Richard', 'last_name': 'Jalichandra', 'permalink': 'richard-jalichandra'}}, {'is_past': True, 'title': 'CEO', 'person': {'first_name': 'Richard', 'last_name': 'Jalichandra', 'permalink': 'richard-jalichandra'}}, {'is_past': True, 'title': 'Chief Financial Officer', 'person': {'first_name': 'Teresa', 'last_name': 'Malo', 'permalink': 'teresa-malo'}}, {'is_past': True, 'title': 'VP of Sales', 'person': {'first_name': 'Karin', 'last_name': 'Marke', 'permalink': 'karin-marke-2'}}, {'is_past': True, 'title': 'VP Business Development', 'person': {'first_name': 'Ted', 'last_name': 'Shelton', 'permalink': 'ted-shelton'}}, {'is_past': True, 'title': 'VP of Marketing', 'person': {'first_name': 'Jennifer', 'last_name': 'McLean', 'permalink': 'jennifer-mclean'}}, {'is_past': True, 'title': 'VP of Engineering', 'person': {'first_name': 'Dorion', 'last_name': 'Carroll', 'permalink': 'dorion-carroll'}}, {'is_past': True, 'title': 'Chairman of the Executi ...
# {'_id': ObjectId('52cdef7c4bab8bd675297da6'), 'name': 'SpinVox', 'permalink': 'spinvox', 'crunchbase_url': 'http://www.crunchbase.com/company/spinvox', 'homepage_url': 'http://www.spinvox.com', 'blog_url': 'http://blog.spinvox.com/', 'blog_feed_url': 'http://blog.spinvox.com/feed/', 'twitter_username': None, 'category_code': 'messaging', 'number_of_employees': None, 'founded_year': None, 'founded_month': None, 'founded_day': None, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'voicetotext', 'alias_list': '', 'email_address': 'service@spinvox.com', 'phone_number': '+44 207 965 2000', 'description': 'Voice to Text service', 'created_at': 'Wed Dec 05 04:08:03 UTC 2007', 'updated_at': 'Fri Apr 22 01:20:20 UTC 2011', 'overview': '<p>Spinvox is a voice to text service. Spinvox started with their (now patented) Voice Message Conversion System in 2005, becoming one of the first companies to convert voicemails to text messages for both landlines and mobile telephones. Users subscribed to the service have incoming voicemail converted and sent as text messages to their mobile phone or emails in their inbox.</p>\n\n<p>In order to compete with other similar service providers, Spinvox has recently introduced some other features such as SpinVox Blog; it allows users speak a post to a blog from any phone. There is also the Memo service: users speak memos to themselves &#8211; the messages subsequently get transcribed and sent as email reminders. Lastly, SpinVox users can speak a text message, update social networks, or send messages to groups of people at once using recepient lists.</p>\n\n<p>SpinVox is the only voicemail-to-text conversion service available in six languages: English, French, Spanish, German, Portuguese and Italian.  </p>\n\n<p>Competitors include: <a href="http://www.crunchbase.com/company/jott" title="Jott">Jott</a>, <a href="http://www.simulscribe.com" title="Simulscribe" rel="nofollow">Simulscribe</a> and <a href="http://www.crunchbase.com/company/pinger" title="Pinger">Pinger</a>.</p>', 'image': {'available_sizes': [[[150, 33], 'assets/images/resized/0000/2488/2488v3-max-150x150.png'], [[200, 45], 'assets/images/resized/0000/2488/2488v3-max-250x250.png'], [[200, 45], 'assets/images/resized/0000/2488/2488v3-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'SpinVox', 'permalink': 'spinvox'}], 'relationships': [{'is_past': False, 'title': 'Chief Strategy Officer and Co-founder', 'person': {'first_name': 'Daniel', 'last_name': 'Doulton', 'permalink': 'daniel-doulton'}}, {'is_past': False, 'title': 'Chief Technology Officer', 'person': {'first_name': 'Philip', 'last_name': 'Marnick', 'permalink': 'philip-marnick'}}, {'is_past': False, 'title': 'Chief Financial Officer', 'person': {'first_name': 'Andrew', 'last_name': 'Cherry', 'permalink': 'andrew-cherry'}}, {'is_past': False, 'title': 'VP Consumer Business', 'person': {'first_name': 'James', 'last_name': 'Scroggs', 'permalink': 'james-scroggs'}}, {'is_past': False, 'title': 'Chief Commercial Officer', 'person': {'first_name': 'Tom', 'last_name': 'Clear', 'permalink': 'tom-clear'}}, {'is_past': False, 'title': 'Chief Information Officer', 'person': {'first_name': 'Rob', 'last_name': 'Wheatley', 'permalink': 'rob-wheatley'}}, {'is_past': True, 'title': 'CEO and Co-founder', 'person': {'first_name': 'Christina', 'last_name': 'Domecq', 'permalink': 'christina-domecq'}}, {'is_past': True, 'title': 'Executive Vice President', 'person': {'first_name': 'Alan', 'last_name': 'Coad', 'permalink': 'alan-coad'}}, {'is_past': True, 'title': 'German and English Quality Manager', 'person': {'first_name': 'Nicole Y.', 'last_name': 'Adams', 'permalink': 'nicole-y-adams'}}, {'is_past': True, 'title': 'Product Manager', 'person': {'first_name': 'Gordon', 'last_name': 'Bazeley', 'permalink': 'gordon-bazeley'}}, {'is_past': True, 'title': 'Director of Product Marketing, Asia Pacific', 'person': {'first_name': 'Stuart' ...
# {'_id': ObjectId('52cdef7c4bab8bd675297da7'), 'name': 'AddThis', 'permalink': 'addthis', 'crunchbase_url': 'http://www.crunchbase.com/company/addthis', 'homepage_url': 'http://www.addthis.com', 'blog_url': 'http://addthis.com/blog', 'blog_feed_url': 'http://addthis.com/blog/feed', 'twitter_username': 'addthis', 'category_code': 'advertising', 'number_of_employees': 120, 'founded_year': 2004, 'founded_month': None, 'founded_day': None, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'sharing, social-applications, social-media, analytics, audience-targeting, advertising-solutions, web-plugins, consumer-engagement-tools, big-data', 'alias_list': 'Clearspring,Clearspring Technologies', 'email_address': 'info@addthis.com', 'phone_number': '703-677-3999', 'description': 'Content Engagement', 'created_at': 'Wed Jun 13 09:00:07 UTC 2007', 'updated_at': 'Thu Dec 05 23:54:22 UTC 2013', 'overview': '<p>AddThis personalizes the web with powerful, easy-to-use social engagement tools, APIs and services. Reaching 1.5 billion unique users monthly, AddThis’ data-driven solutions boost traffic, engagement, intelligence and monetization for publishers and advertisers. With a massive web-wide footprint of more than 14 million domains, AddThis processes more than 300 terabytes of data daily allowing AddThis to provide brands with sophisticated audience models, data-driven engagement tools and web-wide audience insights that enhance paid, earned and owned media strategies.</p>', 'image': {'available_sizes': [[[150, 42], 'assets/images/resized/0000/4135/4135v5-max-150x150.jpg'], [[250, 70], 'assets/images/resized/0000/4135/4135v5-max-250x250.jpg'], [[450, 127], 'assets/images/resized/0000/4135/4135v5-max-450x450.jpg']], 'attribution': None}, 'products': [{'name': 'Publisher Solutions', 'permalink': 'addthis'}, {'name': 'Advertiser Solutions', 'permalink': 'add-this'}, {'name': 'Data Solutions', 'permalink': 'audience-platform'}], 'relationships': [{'is_past': False, 'title': 'CEO', 'person': {'first_name': 'Richard', 'last_name': 'Harris', 'permalink': 'richard-harris-5'}}, {'is_past': False, 'title': 'Founder', 'person': {'first_name': 'Dom', 'last_name': 'Vonarburg', 'permalink': 'dom-vonarburg'}}, {'is_past': False, 'title': 'Co-Founder and Chairman', 'person': {'first_name': 'Hooman', 'last_name': 'Radfar', 'permalink': 'hooman-radfar'}}, {'is_past': False, 'title': 'Chief Product Officer', 'person': {'first_name': 'Andy', 'last_name': 'Spillane', 'permalink': 'andy-spillane'}}, {'is_past': False, 'title': 'Vice President of Client Solutions', 'person': {'first_name': 'Greg', 'last_name': 'Cypes', 'permalink': 'greg-cypes'}}, {'is_past': False, 'title': 'Vice President of User Experience', 'person': {'first_name': 'Jim', 'last_name': 'Lane', 'permalink': 'jim-lane'}}, {'is_past': False, 'title': 'President of Advertiser and Publisher Solutions', 'person': {'first_name': 'Peggy', 'last_name': 'Fry', 'permalink': 'peggy-fry'}}, {'is_past': False, 'title': 'Board Member', 'person': {'first_name': 'Ted', 'last_name': 'Leonsis', 'permalink': 'ted-leonsis'}}, {'is_past': False, 'title': 'Board Member', 'person': {'first_name': 'Harry', 'last_name': 'Weller', 'permalink': 'harry-weller'}}, {'is_past': False, 'title': 'Board Member', 'person': {'first_name': 'Bill', 'last_name': 'Wise', 'permalink': 'bill-wire'}}, {'is_past': False, 'title': 'Board Observer', 'person': {'first_name': 'Sandy', 'last_name': 'Miller', 'permalink': 'sandy-miller'}}, {'is_past': False, 'title': 'General Counsel', 'person': {'first_name': 'Mike', 'last_name': 'McGowan', 'permalink': 'mike-mcgowan'}}, {'is_past': False, 'title': 'Board Member', 'person': {'first_name': 'Steve', 'last_name': 'Case', 'permalink': 'steve-case'}}, {'is_past': False, 'title': 'Investor', 'person': {'first_name': 'Pejman', 'last_name': 'Nozad', 'permalink': 'pejman-nozad'}}, {'is_past': False, 'title': 'Vice President of Product', 'perso ...
# {'_id': ObjectId('52cdef7c4bab8bd675297d8e'), 'name': 'Facebook', 'permalink': 'facebook', 'crunchbase_url': 'http://www.crunchbase.com/company/facebook', 'homepage_url': 'http://facebook.com', 'blog_url': 'http://blog.facebook.com', 'blog_feed_url': 'http://blog.facebook.com/atom.php', 'twitter_username': 'facebook', 'category_code': 'social', 'number_of_employees': 5299, 'founded_year': 2004, 'founded_month': 2, 'founded_day': 1, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': '', 'tag_list': 'facebook, college, students, profiles, network, online-communities, social-networking', 'alias_list': '', 'email_address': '', 'phone_number': '', 'description': 'Social network', 'created_at': 'Fri May 25 21:22:15 UTC 2007', 'updated_at': 'Thu Nov 21 19:40:55 UTC 2013', 'overview': '<p>Facebook is the world&#8217;s largest social network, with over <a href="http://techcrunch.com/2013/07/24/facebook-growth-2/" title="1.15 billion monthly active users">1.15 billion monthly active users</a>.</p>\n\n<p>Facebook was founded by <a href="http://www.crunchbase.com/person/mark-zuckerberg" title="Mark Zuckerberg">Mark Zuckerberg</a> in February 2004, initially as an exclusive network for Harvard students. It was a huge hit: in 2 weeks, half of the schools in the Boston area began demanding a Facebook network. Zuckerberg immediately recruited his friends <a href="http://www.crunchbase.com/person/dustin-moskovitz" title="Dustin Moskovitz">Dustin Moskovitz</a>, <a href="/person/chris-hughes" title="Chris Hughes" rel="nofollow">Chris Hughes</a>, and <a href="/person/eduardo-saverin" title="Eduardo Saverin" rel="nofollow">Eduardo Saverin</a> to help build Facebook, and within four months, Facebook added 30 more college networks. </p>\n\n<p>The original idea for the term Facebook came from Zuckerberg&#8217;s high school (Phillips Exeter Academy). The Exeter Face Book was passed around to every student as a way for students to get to know their classmates for the following year. It was a physical paper book until Zuckerberg brought it to the internet.</p>\n\n<p>With this success, Zuckerberg, Moskowitz and Hughes moved out to <a href="/maps/city/Palo%2520Alto" title="Palo Alto" rel="nofollow">Palo Alto</a> for the summer and rented a sublet. A few weeks later, Zuckerberg ran into the former cofounder of <a href="/company/napster" title="Napster" rel="nofollow">Napster</a>, <a href="/person/sean-parker" title="Sean Parker" rel="nofollow">Sean Parker</a>. Parker soon moved in to Zuckerberg&#8217;s apartment and they began working together.  Parker provided the introduction to their first investor, <a href="/person/peter-thiel" title="Peter Thiel" rel="nofollow">Peter Thiel</a>, cofounder of <a href="/company/paypal" title="PayPal" rel="nofollow">PayPal</a> and managing partner of <a href="http://www.crunchbase.com/financial-organization/founders-fund" title="The Founders Fund">The Founders Fund</a>. Thiel invested $500,000 into Facebook. </p>\n\n<p>With millions more users, <a href="/company/friendster" title="Friendster" rel="nofollow">Friendster</a> <a href="http://www.techcrunch.com/2006/12/12/yahoos-project-fraternity-docs-leaked/" title="attempted">attempted</a> to acquire the company for $10 million in mid 2004. Facebook turned down the offer and subsequently received $12.7 million in funding from <a href="http://www.crunchbase.com/financial-organization/accel-partners" title="Accel Partners">Accel Partners</a>, at a valuation of <a href="http://www.techcrunch.com/2005/09/07/85-of-college-students-use-facebook/" title="around $100 million">around $100 million</a>. Facebook continued to grow, opening up to high school students in September 2005 and adding an immensely popular photo sharing feature the next month. The next spring, Facebook received $25 million in funding from <a href="http://www.crunchbase.com/financial-organization/greylock" title="Greylock Partners">Greylock Partners</a> and <a href="htt ...
# {'_id': ObjectId('52cdef7c4bab8bd675297d8f'), 'name': 'Omnidrive', 'permalink': 'omnidrive', 'crunchbase_url': 'http://www.crunchbase.com/company/omnidrive', 'homepage_url': 'http://www.omnidrive.com', 'blog_url': 'http://www.omnidrive.com/blog', 'blog_feed_url': 'http://feeds.feedburner.com/omnidrive', 'twitter_username': 'Nomadesk', 'category_code': 'network_hosting', 'number_of_employees': None, 'founded_year': 2005, 'founded_month': 11, 'founded_day': 1, 'deadpooled_year': 2008, 'deadpooled_month': 9, 'deadpooled_day': 15, 'deadpooled_url': '', 'tag_list': 'storage, sharing, edit, online', 'alias_list': None, 'email_address': 'info@omnidrive.com', 'phone_number': '660-675-5052', 'description': None, 'created_at': 'Sun May 27 03:25:32 UTC 2007', 'updated_at': 'Tue Jul 02 22:48:04 UTC 2013', 'overview': '<p>Currently in public beta, Omnidrive makes it easy to access, edit and share your files from any computer with a web browser. The site was founded in late 2004 by Nik Cubrilovic and later launched at the November 2006 Web 2.0 Conference.  An interesting slew of features make Omnidrive an attractive choice in the online file storage field.</p>\n\n<p>Omnidrive&#8217;s competitors include <a href="http://www.crunchbase.com/company/box-net" title="Box.net">Box.net</a>, <a href="http://www.streamload.com" title="Streamload" rel="nofollow">Streamload</a> and <a href="http://www.xdrive.com" title="Xdrive" rel="nofollow">Xdrive</a>.</p>', 'image': {'available_sizes': [[[150, 85], 'assets/images/resized/0000/0823/823v1-max-150x150.jpg'], [[150, 85], 'assets/images/resized/0000/0823/823v1-max-250x250.jpg'], [[150, 85], 'assets/images/resized/0000/0823/823v1-max-450x450.jpg']], 'attribution': None}, 'products': [{'name': 'Omnidrive', 'permalink': 'omnidrive'}], 'relationships': [{'is_past': True, 'title': 'Co-founder', 'person': {'first_name': 'Geoff', 'last_name': 'McQueen', 'permalink': 'geoff-mcqueen'}}, {'is_past': True, 'title': 'Founder & CEO', 'person': {'first_name': 'Nik', 'last_name': 'Cubrilovic', 'permalink': 'nik-cubrilovic'}}, {'is_past': True, 'title': '', 'person': {'first_name': 'Tony', 'last_name': 'Guntharp', 'permalink': 'tony-guntharp'}}, {'is_past': True, 'title': 'Board of Advisors', 'person': {'first_name': 'Mike', 'last_name': 'Cannon-Brookes', 'permalink': 'mike-cannon-brookes'}}], 'competitions': [{'competitor': {'name': 'Dropbox', 'permalink': 'dropbox'}}, {'competitor': {'name': 'filobite', 'permalink': 'filobite'}}, {'competitor': {'name': 'digitalbucket.net', 'permalink': 'digitalbucket'}}, {'competitor': {'name': 'ElephantDrive', 'permalink': 'elephantdrive'}}, {'competitor': {'name': 'Banckle Customer Service 2.0', 'permalink': 'banckle'}}], 'providerships': [], 'total_money_raised': '$800k', 'funding_rounds': [{'id': 225, 'round_code': 'angel', 'source_url': '', 'source_description': '', 'raised_amount': 800000, 'raised_currency_code': 'USD', 'funded_year': 2006, 'funded_month': 12, 'funded_day': 1, 'investments': [{'company': None, 'financial_org': None, 'person': {'first_name': 'Michael', 'last_name': 'Arrington', 'permalink': 'michael-arrington'}}, {'company': None, 'financial_org': None, 'person': {'first_name': 'Aydin', 'last_name': 'Senkut', 'permalink': 'aydin-senkut'}}, {'company': None, 'financial_org': None, 'person': {'first_name': 'Georges', 'last_name': 'Harik', 'permalink': 'georges-harik'}}, {'company': None, 'financial_org': None, 'person': {'first_name': 'Jeff', 'last_name': 'Clavier', 'permalink': 'jeff-clavier'}}]}], 'investments': [], 'acquisition': None, 'acquisitions': [], 'offices': [{'description': '', 'address1': 'Suite 200', 'address2': '654 High Street', 'zip_code': '94301', 'city': 'Palo Alto', 'state_code': 'CA', 'country_code': 'ISR', 'latitude': None, 'longitude': None}], 'milestones': [], 'ipo': None, 'video_embeds': [], 'screenshots': [], 'external_links': [], 'partners': []}

# %% [markdown]
# #### Tâche 1.2 : Extraction par secteur d'activité
# - Récupérez la répartition des entreprises par secteur d'activité. Classez les résultats par le nombre d'entreprises par secteur de manière décroissante.
#
#   - Affichez les 5 secteurs avec le plus grand nombre d'entreprises.

# %%
for secteur in db.companies.aggregate([
    {"$group": {"_id": "$category_code", "nombreEntreprises": { "$sum": 1 }}},
    {"$sort": {"nombreEntreprises": -1}},
    {"$limit": 6}
]):
    if secteur["_id"] is not None:
      print(secteur)
# Out:
# {'_id': 'web', 'nombreEntreprises': 1947}
# {'_id': 'software', 'nombreEntreprises': 1356}
# {'_id': 'games_video', 'nombreEntreprises': 528}
# {'_id': 'mobile', 'nombreEntreprises': 520}
# {'_id': 'advertising', 'nombreEntreprises': 476}

# %% [markdown]
# #### Tâche 1.3 : Extraction des entreprises fondées après l'an 2000
# - Récupérez la liste des entreprises fondées après l'an 2000 et triées par année de fondation.

# %%
for company in db.companies.find({ "founded_year": { "$gt": 2000 } }).sort("founded_year",1).limit(10):
    print(company)
# Out:
# {'_id': ObjectId('52cdef7c4bab8bd675297f42'), 'name': 'ChannelAdvisor', 'permalink': 'channeladvisor', 'crunchbase_url': 'http://www.crunchbase.com/company/channeladvisor', 'homepage_url': 'http://www.channeladvisor.com', 'blog_url': 'http://blog.channeladvisor.com/', 'blog_feed_url': 'http://blog.channeladvisor.com/feed/', 'twitter_username': 'channeladvisor', 'category_code': 'search', 'number_of_employees': 300, 'founded_year': 2001, 'founded_month': 7, 'founded_day': None, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'ebay, digitallocker, saas, software-as-a-service, digitalmarketplace, paid-search, come-auctionparison-shopping-engines, online-shopping, marketplace, ecommerce, sell, auction, digitalgoods, e-auction', 'alias_list': '', 'email_address': '', 'phone_number': '', 'description': 'E-commerce service', 'created_at': 'Sat Aug 25 14:27:20 UTC 2007', 'updated_at': 'Wed Jul 17 10:56:35 UTC 2013', 'overview': '<p>ChannelAdvisor is a leading provider of cloud-based e-commerce solutions that enable retailers and manufacturers to increase the scale and profitability of their global sales through dozens of online channels including Amazon, Google, eBay, Facebook and more.   Through automation, analytics and optimization, ChannelAdvisor leverages a single inventory feed to more efficiently list and advertise products online, connecting suppliers with shoppers to increase sales.  Billions of dollars in sales are driven through ChannelAdvisor every year, and thousands of customers such as Eddie Bauer, Jockey and eBags depend on ChannelAdvisor to substantially grow their businesses.  </p>\n\n<p>ChannelAdvisor is headquartered in Research Triangle Park, NC. For further information, visit www.channeladvisor.com.</p>', 'image': {'available_sizes': [[[150, 73], 'assets/images/resized/0015/7146/157146v2-max-150x150.jpg'], [[176, 86], 'assets/images/resized/0015/7146/157146v2-max-250x250.jpg'], [[176, 86], 'assets/images/resized/0015/7146/157146v2-max-450x450.jpg']], 'attribution': None}, 'products': [], 'relationships': [{'is_past': False, 'title': 'President, CEO, Board Member and Co-Founder', 'person': {'first_name': 'Scot', 'last_name': 'Wingo', 'permalink': 'scot-wingo'}}, {'is_past': False, 'title': 'Chief Marketing Officer', 'person': {'first_name': 'Suzanne', 'last_name': 'Miglucci', 'permalink': 'suzanne-miglucci'}}, {'is_past': False, 'title': 'Chief Financial Officer', 'person': {'first_name': 'John', 'last_name': 'Baule', 'permalink': 'john-baule'}}, {'is_past': False, 'title': 'President & COO', 'person': {'first_name': 'David', 'last_name': 'Spitz', 'permalink': 'david-spitz'}}, {'is_past': False, 'title': 'Chief Technology Officer, Board Member and Co-Founder', 'person': {'first_name': 'Aris', 'last_name': 'Buinevicius', 'permalink': 'aris-buinevicius'}}, {'is_past': False, 'title': 'Vice President of Product Management', 'person': {'first_name': 'Link', 'last_name': 'Walls', 'permalink': 'link-walls'}}, {'is_past': False, 'title': 'Vice President of Finance', 'person': {'first_name': 'Brad', 'last_name': 'Schomber', 'permalink': 'brad-schomber'}}, {'is_past': False, 'title': 'Vice President of Enterprise Sales', 'person': {'first_name': 'Paul', 'last_name': 'Colucci', 'permalink': 'paul-colucci'}}, {'is_past': False, 'title': 'Vice President and General Counsel', 'person': {'first_name': 'Scott', 'last_name': 'Alridge', 'permalink': 'scott-alridge'}}, {'is_past': False, 'title': 'Board of Directors', 'person': {'first_name': 'Patrick', 'last_name': 'Kerins', 'permalink': 'patrick-kerins'}}, {'is_past': False, 'title': 'Vice President of Global Services', 'person': {'first_name': 'Thad', 'last_name': 'Tremaine', 'permalink': 'thad-tremaine'}}, {'is_past': False, 'title': 'Vice President of Engineering', 'person': {'first_name': 'Tat', 'last_name': 'Ng', 'permalink': 'tat-ng'}}, {'is_past': False, 'title': 'Board of Director', 'person': {'first_name': 'L ...
# {'_id': ObjectId('52cdef7c4bab8bd675297ef0'), 'name': 'SuicideGirls', 'permalink': 'suicidegirls', 'crunchbase_url': 'http://www.crunchbase.com/company/suicidegirls', 'homepage_url': 'http://suicidegirls.com', 'blog_url': '', 'blog_feed_url': '', 'twitter_username': 'SuicideGirls', 'category_code': 'web', 'number_of_employees': None, 'founded_year': 2001, 'founded_month': 9, 'founded_day': None, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'pinup, girls, photos, alternative, nude, adult, suicidegirls, howtobeasuicidegirl, seizure, nudephoto', 'alias_list': '', 'email_address': 'shop@suicidegirls.com', 'phone_number': '(323) 667-9000', 'description': '', 'created_at': 'Mon Aug 20 15:12:54 UTC 2007', 'updated_at': 'Thu Apr 04 04:34:43 UTC 2013', 'overview': '<p>SuicideGirls features pin-up pictures of over 1500 alternative models.  Many of the models have tattoos, piercings and other physical traits that don&#8217;t match up with those of mainstream models.  The site was originally started by a pair of people in Portland &#8220;just to see hot punk rock girls naked.&#8221;  It has since grown to have an audience of over 5 million unique visitors per month.  In addition to the site, SuicideGirls has produced a book, dvds, and a clothing line.</p>', 'image': {'available_sizes': [[[83, 100], 'assets/images/resized/0000/4408/4408v1-max-150x150.png'], [[83, 100], 'assets/images/resized/0000/4408/4408v1-max-250x250.png'], [[83, 100], 'assets/images/resized/0000/4408/4408v1-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'SuicideGirls', 'permalink': 'suicidegirls'}], 'relationships': [{'is_past': False, 'title': 'Co-Founder', 'person': {'first_name': 'Selena', 'last_name': 'Mooney', 'permalink': 'selena-mooney'}}, {'is_past': False, 'title': 'Co-Founder', 'person': {'first_name': 'Sean', 'last_name': 'Suhl', 'permalink': 'sean-suhl'}}], 'competitions': [{'competitor': {'name': 'Red Light Center', 'permalink': 'redlightcenter'}}], 'providerships': [], 'total_money_raised': '$0', 'funding_rounds': [], 'investments': [], 'acquisition': None, 'acquisitions': [], 'offices': [{'description': None, 'address1': '5482 Wilshire Blvd. #1925', 'address2': None, 'zip_code': '90036', 'city': 'Los Angeles', 'state_code': None, 'country_code': 'USA', 'latitude': 34.062262, 'longitude': -118.348198}], 'milestones': [], 'ipo': None, 'video_embeds': [], 'screenshots': [], 'external_links': [{'external_url': 'http://myspace.com/suicidegirls', 'title': 'SuicideGirls MySpace Page'}], 'partners': []}
# {'_id': ObjectId('52cdef7c4bab8bd675298272'), 'name': 'skinnyCorp', 'permalink': 'skinnycorp', 'crunchbase_url': 'http://www.crunchbase.com/company/skinnycorp', 'homepage_url': 'http://skinnycorp.com', 'blog_url': '', 'blog_feed_url': '', 'twitter_username': None, 'category_code': 'web', 'number_of_employees': 45, 'founded_year': 2001, 'founded_month': 1, 'founded_day': 21, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': '', 'tag_list': '', 'alias_list': None, 'email_address': 'info@skinnycorp.com', 'phone_number': '7738783557', 'description': None, 'created_at': 'Tue Feb 12 04:34:30 UTC 2008', 'updated_at': 'Tue Aug 20 10:13:09 UTC 2013', 'overview': '<p>skinnyCorp is a company with a lot of style.  They produce well-designed, fresh websites, with their main one being <a href="http://www.threadless.com" title="Threadless" rel="nofollow">Threadless</a>, a t-shirt community that allows user-submitted designs.  </p>', 'image': {'available_sizes': [[[150, 54], 'assets/images/resized/0001/1652/11652v1-max-150x150.png'], [[150, 54], 'assets/images/resized/0001/1652/11652v1-max-250x250.png'], [[150, 54], 'assets/images/resized/0001/1652/11652v1-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'Threadless', 'permalink': 'threadless-com'}, {'name': 'Extratasty.com', 'permalink': 'extratasty-com'}], 'relationships': [{'is_past': False, 'title': 'Co-Founder', 'person': {'first_name': 'Jake', 'last_name': 'Nickell', 'permalink': 'jake-nickell'}}, {'is_past': False, 'title': 'CEO', 'person': {'first_name': 'Tom', 'last_name': 'Ryan', 'permalink': 'tom-ryan'}}, {'is_past': True, 'title': 'Founder', 'person': {'first_name': 'Jacob', 'last_name': 'DeHart', 'permalink': 'jacob-dehart'}}, {'is_past': True, 'title': 'Chief Creative Officer', 'person': {'first_name': 'Jeffrey', 'last_name': 'Kalmikoff', 'permalink': 'jeffrey-kalmikoff'}}, {'is_past': True, 'title': 'CTO', 'person': {'first_name': 'Harper', 'last_name': 'Reed', 'permalink': 'harper-reed'}}, {'is_past': True, 'title': 'Community Partnerships Manager', 'person': {'first_name': 'Christian', 'last_name': 'Picciolini', 'permalink': 'christian-picciolini'}}, {'is_past': True, 'title': 'Senior Software Engineer', 'person': {'first_name': 'Chad', 'last_name': 'Paulson', 'permalink': 'chad-paulson'}}], 'competitions': [], 'providerships': [], 'total_money_raised': '$0', 'funding_rounds': [], 'investments': [], 'acquisition': None, 'acquisitions': [], 'offices': [{'description': None, 'address1': '4043 N Ravenswood ave', 'address2': 'suite 106', 'zip_code': '60613', 'city': 'chicago', 'state_code': 'IL', 'country_code': 'USA', 'latitude': 41.955054, 'longitude': -87.673059}], 'milestones': [], 'ipo': None, 'video_embeds': [], 'screenshots': [], 'external_links': [{'external_url': 'http://threadless.com', 'title': 'threadless'}], 'partners': []}
# {'_id': ObjectId('52cdef7c4bab8bd675298114'), 'name': 'Localeze', 'permalink': 'localeze', 'crunchbase_url': 'http://www.crunchbase.com/company/localeze', 'homepage_url': 'http://www.localeze.com', 'blog_url': '', 'blog_feed_url': '', 'twitter_username': 'Localeze', 'category_code': 'search', 'number_of_employees': 1, 'founded_year': 2001, 'founded_month': 10, 'founded_day': 1, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'local-search, yellowpages, business-listings, content', 'alias_list': '', 'email_address': 'support@localeze.com', 'phone_number': '800.960.3755', 'description': '', 'created_at': 'Wed Nov 21 16:49:46 UTC 2007', 'updated_at': 'Sat Mar 23 11:45:04 UTC 2013', 'overview': '<p>Localeze, a service of Neustar, is a business listings identity manager for local search. The company maintains direct, authorized relationships with local search platforms, national and regional brands, channel partners and local businesses. The company provides businesses with tools to verify, manage and enhance the identity of their local listings across the Web. Localeze is a privately held company headquartered in Vienna, Virginia.</p>', 'image': {'available_sizes': [[[150, 44], 'assets/images/resized/0000/2272/2272v7-max-150x150.png'], [[250, 74], 'assets/images/resized/0000/2272/2272v7-max-250x250.png'], [[320, 95], 'assets/images/resized/0000/2272/2272v7-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'Localeze', 'permalink': 'localeze'}], 'relationships': [{'is_past': False, 'title': 'Chairman', 'person': {'first_name': 'George', 'last_name': 'Moore', 'permalink': 'george-moore'}}, {'is_past': False, 'title': 'CIO', 'person': {'first_name': 'Steve', 'last_name': 'Chudleigh', 'permalink': 'steve-chudleigh'}}, {'is_past': False, 'title': 'Vice President of Marketing', 'person': {'first_name': 'David', 'last_name': 'Dague', 'permalink': 'david-dague'}}, {'is_past': False, 'title': 'Vice President of Content Distribution', 'person': {'first_name': 'Brian', 'last_name': 'Wool', 'permalink': 'brian-wool'}}, {'is_past': False, 'title': 'President', 'person': {'first_name': 'Jeff', 'last_name': 'Beard', 'permalink': 'jeff-beard'}}, {'is_past': False, 'title': 'Vice President of Market Development', 'person': {'first_name': 'Gib', 'last_name': 'Olander', 'permalink': 'gib-olander'}}, {'is_past': False, 'title': 'Vice President of Content Acquisition', 'person': {'first_name': 'Andy', 'last_name': 'Gordon', 'permalink': 'andy-gordon'}}, {'is_past': True, 'title': 'Founding Executive', 'person': {'first_name': 'Karen', 'last_name': 'Kovaleski', 'permalink': 'karen-kovaleski'}}], 'competitions': [{'competitor': {'name': 'Universal Business Listings', 'permalink': 'universal-business-listings'}}], 'providerships': [], 'total_money_raised': '$0', 'funding_rounds': [], 'investments': [], 'acquisition': None, 'acquisitions': [], 'offices': [{'description': 'Headquarters', 'address1': '8010 Towers Center Drive Fifth Floor', 'address2': '', 'zip_code': '22182', 'city': 'Vienna', 'state_code': 'VA', 'country_code': 'USA', 'latitude': 41.878643, 'longitude': -87.636706}], 'milestones': [], 'ipo': None, 'video_embeds': [], 'screenshots': [{'available_sizes': [[[150, 111], 'assets/images/resized/0007/3610/73610v2-max-150x150.png'], [[250, 185], 'assets/images/resized/0007/3610/73610v2-max-250x250.png'], [[450, 334], 'assets/images/resized/0007/3610/73610v2-max-450x450.png']], 'attribution': None}], 'external_links': [{'external_url': 'http://blog.searchenginewatch.com/100721-073437', 'title': 'Search Engine Watch'}], 'partners': []}
# {'_id': ObjectId('52cdef7c4bab8bd675297e9f'), 'name': 'Userplane', 'permalink': 'userplane', 'crunchbase_url': 'http://www.crunchbase.com/company/userplane', 'homepage_url': 'http://www.userplane.com', 'blog_url': 'http://www.userplane.com/blog/', 'blog_feed_url': 'http://www.userplane.com/blog/feed/', 'twitter_username': 'userplane', 'category_code': 'enterprise', 'number_of_employees': 10, 'founded_year': 2001, 'founded_month': 1, 'founded_day': 1, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'userplane, chat, video-chat, audio-chat, xmpp, white-label, instant-messenging, wall-garden, real-time-presence', 'alias_list': None, 'email_address': 'support@userplane.com', 'phone_number': '+1 (310) 285-4339', 'description': 'Hosted Video Chat', 'created_at': 'Sat Aug 04 10:37:57 UTC 2007', 'updated_at': 'Tue Oct 23 03:10:58 UTC 2012', 'overview': '<p>Founded in 2001 and <a href="http://www.techcrunch.com/2006/08/14/userplane-purchased-by-aol/" title="acquired by AOL">acquired by AOL</a> in 2006, Userplane is a hosted social discovery platform. Userplane likes to consider itself more as Social-as-a-service, backing the belief that helping its partners integrate Userplane can transform their online community and their business.</p>\n\n<p>The real-time messaging features of the Userplane platform empower customers to deliver rich, engaging experiences to users, connecting them with the community and the content. As a white-label service, Userplane features can be implemented in a way that preserves and enhances the integrity of the customer&#8217;s brand.</p>\n\n<p>Competitors include <a href="http://techcrunch.com/search/flashcoms" title="FlashComs">FlashComs</a>, <a href="http://techcrunch.com/search/avchat" title="AVChat">AVChat</a>, and <a href="http://techcrunch.com/tag/meebo/" title="Meebo">Meebo</a>.</p>', 'image': {'available_sizes': [[[150, 46], 'assets/images/resized/0000/4039/4039v17-max-150x150.png'], [[212, 66], 'assets/images/resized/0000/4039/4039v17-max-250x250.png'], [[212, 66], 'assets/images/resized/0000/4039/4039v17-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'Webchat', 'permalink': 'webchat'}, {'name': 'Webrecorder', 'permalink': 'webrecorder'}, {'name': 'Webmessenger3', 'permalink': 'webmessenger3'}, {'name': 'Webchat Lite', 'permalink': 'webchat-lite'}, {'name': 'Presencebar', 'permalink': 'presencebar'}], 'relationships': [{'is_past': False, 'title': 'Technical Director', 'person': {'first_name': 'Matthew', 'last_name': 'Turner', 'permalink': 'matthew-turner'}}, {'is_past': False, 'title': 'General Manager', 'person': {'first_name': 'Mary', 'last_name': 'Barnes', 'permalink': 'mary-barnes'}}, {'is_past': True, 'title': 'Founder', 'person': {'first_name': 'Kevin', 'last_name': 'Prentiss', 'permalink': 'kevin-prentiss'}}, {'is_past': True, 'title': 'CEO', 'person': {'first_name': 'Mike', 'last_name': 'Jones', 'permalink': 'mike-jones'}}, {'is_past': True, 'title': 'CTO', 'person': {'first_name': 'Lucas', 'last_name': 'McGregor', 'permalink': 'lucas-mcgregor'}}, {'is_past': True, 'title': 'Owner, CTO', 'person': {'first_name': 'Nate', 'last_name': 'Thelen', 'permalink': 'nate-thelen'}}, {'is_past': True, 'title': 'CCO', 'person': {'first_name': 'Javier', 'last_name': 'Hall', 'permalink': 'javier-hall'}}, {'is_past': True, 'title': 'Business Development', 'person': {'first_name': 'Ian', 'last_name': 'Swanson', 'permalink': 'ian-swanson'}}, {'is_past': True, 'title': 'Inside Sales Account Executive', 'person': {'first_name': 'Ben', 'last_name': 'Staley', 'permalink': 'ben-staley'}}, {'is_past': True, 'title': 'Corporate Counsel', 'person': {'first_name': 'Greg', 'last_name': 'Gilman', 'permalink': 'greg-gilman'}}, {'is_past': True, 'title': 'Director, Media Sales', 'person': {'first_name': 'Justin', 'last_name': 'Ehly', 'permalink': 'justin-ehly'}}, {'is_past': True, 'title': 'Product Manager', 'person': {'first_name': 'Jonathan',  ...
# {'_id': ObjectId('52cdef7c4bab8bd67529815a'), 'name': 'Skyscanner', 'permalink': 'skyscanner', 'crunchbase_url': 'http://www.crunchbase.com/company/skyscanner', 'homepage_url': 'http://www.skyscanner.co.in', 'blog_url': '', 'blog_feed_url': '', 'twitter_username': 'Skyscanner', 'category_code': 'web', 'number_of_employees': 300, 'founded_year': 2001, 'founded_month': 5, 'founded_day': 16, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': 'travel, online-search', 'alias_list': '', 'email_address': '', 'phone_number': '+44 131 252 5353', 'description': 'Travel search site', 'created_at': 'Sun Dec 09 06:38:04 UTC 2007', 'updated_at': 'Thu Oct 10 04:43:45 UTC 2013', 'overview': '<p>Started by three founders in 2003, Skyscanner is a leading global travel search site, providing instant online comparisons for millions of flights on over a thousand airlines, as well as car hire and hotels.</p>\n\n<p>Skyscanner’s flexible search options mean you can browse prices across a whole month, or even a year, allowing you to get the best deals. You always book direct with the airline or travel agent, so you get the lowest price, with no extra fees added.</p>\n\n<p>The site now receives 25 million visitors per month, while the app has been downlaoded over 25 million times. The company has offices in Edinburgh, Miami, Singapore and Beijing employing over 300 staff.</p>', 'image': {'available_sizes': [[[150, 79], 'assets/images/resized/0004/0477/40477v10-max-150x150.png'], [[185, 98], 'assets/images/resized/0004/0477/40477v10-max-250x250.png'], [[185, 98], 'assets/images/resized/0004/0477/40477v10-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'Mobile apps for iOS, Android, Windows Phone and BlackBerry', 'permalink': 'mobile-apps-for-ios-android-windows-phone-and-blackberry'}], 'relationships': [{'is_past': False, 'title': 'Co-founder', 'person': {'first_name': 'Bonamy', 'last_name': 'Grimes', 'permalink': 'bonamy-grimes'}}, {'is_past': False, 'title': 'Co-founder and Chief Executive', 'person': {'first_name': 'Gareth', 'last_name': 'Williams', 'permalink': 'gareth-williams'}}, {'is_past': False, 'title': 'Co-founder', 'person': {'first_name': 'Barry', 'last_name': 'Smith', 'permalink': 'barry-smith'}}, {'is_past': False, 'title': 'Investor', 'person': {'first_name': 'Stuart', 'last_name': 'Paterson', 'permalink': 'stuart-paterson'}}, {'is_past': False, 'title': 'Chairman', 'person': {'first_name': 'Ray', 'last_name': 'Nolan', 'permalink': 'ray-nolan'}}, {'is_past': True, 'title': 'Chairman', 'person': {'first_name': 'John', 'last_name': 'Nicholson', 'permalink': 'john-nicholson'}}, {'is_past': True, 'title': '', 'person': {'first_name': 'David', 'last_name': 'Hilditch', 'permalink': 'david-hilditch'}}], 'competitions': [{'competitor': {'name': 'Wego', 'permalink': 'wego-com'}}], 'providerships': [], 'total_money_raised': '£2.5M', 'funding_rounds': [{'id': 1148, 'round_code': 'a', 'source_url': 'http://www.growingbusiness.co.uk/06959143451379266221/search-engine-skyscanner-set-for-global-coverage.html', 'source_description': '', 'raised_amount': 2500000, 'raised_currency_code': 'GBP', 'funded_year': 2007, 'funded_month': 11, 'funded_day': 1, 'investments': [{'company': None, 'financial_org': {'name': 'Scottish Equity Partners', 'permalink': 'scottish-equity-partners'}, 'person': None}]}, {'id': 50703, 'round_code': 'unattributed', 'source_url': 'http://techcrunch.com/2013/10/02/veteran-travel-search-engine-skyscanner-lands-one-of-largest-sequoia-investments-to-date-at-800m-valuation/', 'source_description': 'Veteran Travel Search Engine Skyscanner Lands “One Of Largest” Sequoia Investments To Date At $800M Valuation', 'raised_amount': None, 'raised_currency_code': 'USD', 'funded_year': 2013, 'funded_month': 10, 'funded_day': 3, 'investments': [{'company': None, 'financial_org': {'name': 'Sequoia Capital', 'permalink': 'sequoia-capital'}, 'person': None}]}], 'investments' ...
# {'_id': ObjectId('52cdef7c4bab8bd6752982dc'), 'name': 'ChoiceStream', 'permalink': 'choicestream', 'crunchbase_url': 'http://www.crunchbase.com/company/choicestream', 'homepage_url': 'http://www.choicestream.com', 'blog_url': 'http://choicestream.com/blog/', 'blog_feed_url': '', 'twitter_username': 'ChoiceStream', 'category_code': 'advertising', 'number_of_employees': 50, 'founded_year': 2001, 'founded_month': 9, 'founded_day': 1, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': '', 'alias_list': None, 'email_address': 'info@choicestream.com', 'phone_number': '(617) 498-7800', 'description': 'High Impact Programmatic Solutions', 'created_at': 'Thu Feb 14 15:56:29 UTC 2008', 'updated_at': 'Thu Jan 02 19:51:17 UTC 2014', 'overview': '<p>ChoiceStream improves ad relevance and digital campaign performance by programmatically selecting optimum advertising opportunities based on a dynamic understanding of consumer’s active preferences. With an extensive first and third party data network enhanced by proprietary data, ChoiceStream can target and convert the most valuable consumers in real-time. ChoiceStream is headquartered in the Innovation District of Boston and works with industry leading brands and their agencies. For more information on ChoiceStream, please visit www.ChoiceStream.com.</p>', 'image': {'available_sizes': [[[150, 108], 'assets/images/resized/0001/2181/12181v5-max-150x150.png'], [[250, 180], 'assets/images/resized/0001/2181/12181v5-max-250x250.png'], [[450, 325], 'assets/images/resized/0001/2181/12181v5-max-450x450.png']], 'attribution': None}, 'products': [], 'relationships': [{'is_past': False, 'title': 'Founder', 'person': {'first_name': 'Steve', 'last_name': 'Johnson', 'permalink': 'steve-johnson'}}, {'is_past': False, 'title': 'Chief Financial Officer', 'person': {'first_name': 'Mark', 'last_name': 'Gallagher', 'permalink': 'mark-gallagher'}}, {'is_past': False, 'title': 'VP of Research & Development', 'person': {'first_name': 'Aidan', 'last_name': 'Cardella', 'permalink': 'aidan-cardella'}}, {'is_past': False, 'title': 'Chief Revenue Officer', 'person': {'first_name': 'Jeff', 'last_name': 'Valente', 'permalink': 'jeff-valente'}}, {'is_past': True, 'title': 'Chief Architect', 'person': {'first_name': 'Greg', 'last_name': 'White', 'permalink': 'greg-white'}}, {'is_past': True, 'title': 'Chief Revenue Officer', 'person': {'first_name': 'Lori', 'last_name': 'Trahan', 'permalink': 'lori-trahan'}}, {'is_past': True, 'title': 'Chief Operating Officer', 'person': {'first_name': 'Darin', 'last_name': 'Hicks', 'permalink': 'darin-hicks'}}, {'is_past': True, 'title': 'Chief Solutions Officer', 'person': {'first_name': 'Dinesh', 'last_name': 'Gopinath', 'permalink': 'dinesh-gopinath'}}, {'is_past': True, 'title': 'Chief Technology Officer', 'person': {'first_name': 'Michael', 'last_name': 'Strickman', 'permalink': 'michael-strickman'}}, {'is_past': True, 'title': 'VP and General Manager', 'person': {'first_name': 'Millie', 'last_name': 'Park', 'permalink': 'millie-park'}}, {'is_past': True, 'title': 'SVP, Professional Services and Product Development', 'person': {'first_name': 'Bob', 'last_name': 'Hiss', 'permalink': 'bob-hiss'}}, {'is_past': True, 'title': 'EVP, Sales and Marketing', 'person': {'first_name': 'Toffer', 'last_name': 'Winslow', 'permalink': 'toffer-winslow'}}, {'is_past': True, 'title': 'EVP, Business Affairs & General Counsel', 'person': {'first_name': 'Doug', 'last_name': 'Feick', 'permalink': 'doug-feick'}}, {'is_past': True, 'title': '', 'person': {'first_name': 'Usama', 'last_name': 'Fayyad', 'permalink': 'usama-fayyad'}}, {'is_past': True, 'title': 'VP, Finance', 'person': {'first_name': 'Peter', 'last_name': 'Basius', 'permalink': 'peter-basius'}}, {'is_past': True, 'title': 'Chief Operating Officer', 'person': {'first_name': 'Eric', 'last_name': 'Bosco', 'permalink': 'eric-bosco'}}, {'is_past': True, 'title': 'VP of Sales', 'person': {'fi ...
# {'_id': ObjectId('52cdef7c4bab8bd6752982a4'), 'name': 'Booyah Networks', 'permalink': 'booyah-networks', 'crunchbase_url': 'http://www.crunchbase.com/company/booyah-networks', 'homepage_url': 'http://www.booyahnetworks.com', 'blog_url': '', 'blog_feed_url': '', 'twitter_username': None, 'category_code': 'web', 'number_of_employees': 42, 'founded_year': 2001, 'founded_month': 5, 'founded_day': 1, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': None, 'alias_list': None, 'email_address': 'support@BooyahNetworks.com', 'phone_number': '303.345.6600', 'description': None, 'created_at': 'Tue Feb 12 21:39:59 UTC 2008', 'updated_at': 'Sat Jan 17 15:03:27 UTC 2009', 'overview': '<p>Booyah Networks is a digital marketing and technologies company. Through our Booyah Agency and SpotXchange Group divisions, we offer the expertise, the technologies, and the distribution to maximize your digital marketing efforts and reach your customers. </p>', 'image': {'available_sizes': [[[150, 20], 'assets/images/resized/0002/6704/26704v1-max-150x150.png'], [[250, 34], 'assets/images/resized/0002/6704/26704v1-max-250x250.png'], [[450, 62], 'assets/images/resized/0002/6704/26704v1-max-450x450.png']], 'attribution': None}, 'products': [], 'relationships': [{'is_past': False, 'title': 'CEO/President', 'person': {'first_name': 'Michael', 'last_name': 'Shehan', 'permalink': 'michael-shehan'}}, {'is_past': False, 'title': 'Founder and COO/CFO', 'person': {'first_name': 'Steven', 'last_name': 'B. Swoboda', 'permalink': 'steven-b-swoboda'}}, {'is_past': False, 'title': 'CTO', 'person': {'first_name': 'J.', 'last_name': 'Allen Dove', 'permalink': 'j-allen-dove'}}, {'is_past': True, 'title': 'Vice President, Business Development, Publishers', 'person': {'first_name': 'Mark', 'last_name': 'Reynolds', 'permalink': 'mark-reynolds'}}, {'is_past': True, 'title': 'Director, Business Development', 'person': {'first_name': 'Josh', 'last_name': 'Cariveau', 'permalink': 'josh-cariveau'}}], 'competitions': [], 'providerships': [], 'total_money_raised': '$0', 'funding_rounds': [], 'investments': [], 'acquisition': None, 'acquisitions': [], 'offices': [{'description': None, 'address1': '11030 CirclePoint Road Suite 350', 'address2': '', 'zip_code': '80020', 'city': 'Westminster', 'state_code': 'CO', 'country_code': 'USA', 'latitude': 39.89674, 'longitude': -105.07359}], 'milestones': [], 'ipo': None, 'video_embeds': [], 'screenshots': [], 'external_links': [], 'partners': []}
# {'_id': ObjectId('52cdef7c4bab8bd675297ed2'), 'name': 'Six Apart', 'permalink': 'six-apart', 'crunchbase_url': 'http://www.crunchbase.com/company/six-apart', 'homepage_url': 'http://www.sixapart.com', 'blog_url': 'http://www.sixapart.com/blog/', 'blog_feed_url': 'http://feeds.feedburner.com/SixApartNews', 'twitter_username': 'sixapart', 'category_code': 'enterprise', 'number_of_employees': 50, 'founded_year': 2001, 'founded_month': 9, 'founded_day': 1, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': '', 'tag_list': 'blogging, cms', 'alias_list': None, 'email_address': 'pr@sixapart.com', 'phone_number': '(415) 344 0056', 'description': 'Blogging and CMS', 'created_at': 'Thu Aug 16 05:02:04 UTC 2007', 'updated_at': 'Fri Jun 14 09:49:48 UTC 2013', 'overview': '<p>Six Apart was formed in 2001 as a blog solution provider in the US. In 2003 the company founded Six Apart KK, a Japanese legal entity. In November 2010, Six Apart joined forces with VideoEgg to create a new company called SAY Media. In January 2011, Six Apart KK was wholly acquired by Infocom, a Japanese IT company listed on the Tokyo Stock Exchange.</p>\n\n<p>Six Apart KK has assumed responsibility over all intellectual property and business operations of Movable Type, as well as trademark rights of Six Apart. The new Six Apart, a Japanese corporation formerly known as Six Apart KK, currently develops, markets and supports Movable Type for a global user base, and also operates the [company&#8217;s website]  (www.sixapart.com).</p>\n\n<p>TypePad and blogs.com are now available from SAY Media. For information on these services, please visit <a href="http://www.saymedia.com/" title="SAY Media" rel="nofollow">SAY Media</a>&#8217;s website.</p>', 'image': {'available_sizes': [[[96, 54], 'assets/images/resized/0000/4339/4339v1-max-150x150.png'], [[96, 54], 'assets/images/resized/0000/4339/4339v1-max-250x250.png'], [[96, 54], 'assets/images/resized/0000/4339/4339v1-max-450x450.png']], 'attribution': None}, 'products': [{'name': 'Vox', 'permalink': 'vox'}, {'name': 'TypePad', 'permalink': 'typepad'}, {'name': 'Movable Type', 'permalink': 'movable-type'}, {'name': 'Blog It', 'permalink': 'blogit'}, {'name': 'TypePad AntiSpam', 'permalink': 'typepad-antispam'}, {'name': 'TypePad Motion', 'permalink': 'typepad-motion'}], 'relationships': [{'is_past': False, 'title': 'President & CEO', 'person': {'first_name': 'Nob', 'last_name': 'Seki', 'permalink': 'nob-seki'}}, {'is_past': False, 'title': 'COO', 'person': {'first_name': 'Hajime', 'last_name': 'Koga', 'permalink': 'hajime-koga'}}, {'is_past': False, 'title': '', 'person': {'first_name': 'Andy', 'last_name': 'Mai', 'permalink': 'andy-mai'}}, {'is_past': False, 'title': 'GM of North America', 'person': {'first_name': 'Robert', 'last_name': 'Minton', 'permalink': 'robert-minton'}}, {'is_past': False, 'title': 'CTO', 'person': {'first_name': 'Daiji', 'last_name': 'Hirata', 'permalink': 'daiji-hirata'}}, {'is_past': True, 'title': 'Chairman', 'person': {'first_name': 'Joi', 'last_name': 'Ito', 'permalink': 'joi-ito'}}, {'is_past': True, 'title': 'CTO & Co-founder', 'person': {'first_name': 'Ben', 'last_name': 'Trott', 'permalink': 'ben-trott'}}, {'is_past': True, 'title': 'CEO & Chairman', 'person': {'first_name': 'Chris', 'last_name': 'Alden', 'permalink': 'chris-alden'}}, {'is_past': True, 'title': 'Chief Financial Officer', 'person': {'first_name': 'Tod', 'last_name': 'Harmon', 'permalink': 'tod-harmon'}}, {'is_past': True, 'title': 'CFO', 'person': {'first_name': 'Tod', 'last_name': 'Harmon', 'permalink': 'tod-harmon'}}, {'is_past': True, 'title': 'Vice President, Customer Service and Business Operations', 'person': {'first_name': 'Doug', 'last_name': 'Bryan', 'permalink': 'doug-bryan'}}, {'is_past': True, 'title': 'EVP & GM Consumer Division', 'person': {'first_name': 'David', 'last_name': 'Tokheim', 'permalink': 'david-tokheim'}}, {'is_past': True, 'title': 'Vice-President, Engineerin ...
# {'_id': ObjectId('52cdef7c4bab8bd675297e1e'), 'name': 'TechnologyGuide', 'permalink': 'technologyguide', 'crunchbase_url': 'http://www.crunchbase.com/company/technologyguide', 'homepage_url': 'http://www.technologyguide.com', 'blog_url': '', 'blog_feed_url': '', 'twitter_username': None, 'category_code': 'web', 'number_of_employees': 10, 'founded_year': 2001, 'founded_month': 10, 'founded_day': 1, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': '', 'tag_list': None, 'alias_list': None, 'email_address': '', 'phone_number': '', 'description': None, 'created_at': 'Thu Aug 23 12:33:07 UTC 2007', 'updated_at': 'Fri Jul 11 21:08:47 UTC 2008', 'overview': None, 'image': None, 'products': [], 'relationships': [], 'competitions': [], 'providerships': [], 'total_money_raised': '$0', 'funding_rounds': [], 'investments': [], 'acquisition': {'price_amount': 15000000, 'price_currency_code': 'USD', 'term_code': 'cash', 'source_url': None, 'source_description': None, 'acquired_year': 2007, 'acquired_month': 4, 'acquired_day': 1, 'acquiring_company': {'name': 'TechTarget', 'permalink': 'techtarget'}}, 'acquisitions': [], 'offices': [{'description': None, 'address1': '7420 Jager Ct', 'address2': '', 'zip_code': '45230', 'city': 'Cincinnati', 'state_code': 'OH', 'country_code': 'USA', 'latitude': 39.06685, 'longitude': -84.351532}], 'milestones': [], 'ipo': None, 'video_embeds': [], 'screenshots': [], 'external_links': [], 'partners': []}

# %% [markdown]
# ### **Étape 2 : Transformation des données**
#
# #### Tâche 2.1 : Répartition géographique des entreprises
# - Transformez les données pour analyser la répartition des entreprises par pays. Regroupez les entreprises par pays et comptez leur nombre pour chaque pays.

# %%
# inpirer de https://www.mongodb.com/docs/manual/reference/operator/aggregation/unwind/

for pays in db.companies.aggregate([
    {"$unwind": "$offices"},
    {"$group": {"_id": "$offices.country_code", "nombreEntreprises": {"$sum": 1}}},
    {"$sort": {"nombreEntreprises": -1}},
    {"$limit": 10}
]):
    print(pays)
# Out:
# {'_id': 'USA', 'nombreEntreprises': 5098}
# {'_id': 'GBR', 'nombreEntreprises': 698}
# {'_id': 'CAN', 'nombreEntreprises': 303}
# {'_id': 'IND', 'nombreEntreprises': 243}
# {'_id': 'DEU', 'nombreEntreprises': 205}
# {'_id': 'FRA', 'nombreEntreprises': 191}
# {'_id': 'ISR', 'nombreEntreprises': 142}
# {'_id': 'AUS', 'nombreEntreprises': 141}
# {'_id': 'ESP', 'nombreEntreprises': 121}
# {'_id': 'NLD', 'nombreEntreprises': 91}

# %% [markdown]
# #### Tâche 2.2 : Analyse des entreprises par taille
# - Utilisez les informations sur le nombre d’employés pour identifier les entreprises ayant plus de 1000 employés. Transformez les données pour regrouper les entreprises par tranche d'effectif (ex. : 0-100 employés, 101-500 employés, etc.).
# Puis sauvegarder le résultat dans un fichier `tache2_2.csv`

# %%
data = db.companies.aggregate([
    {
        "$bucket": {
            "groupBy": "$number_of_employees",
            "boundaries": [0, 101, 501, 1001],
            "default": "1001+",
            "output": {
                "nombreEntreprises": {"$sum": 1}
            }
        }
    }
])

df = pd.DataFrame(data)
df = df.rename(columns={"_id": "effectif"})
df.to_csv('tache2_2.csv')

# %% [markdown]
# #### Tâche 2.3 : Analyse temporelle
# - Transformez les données pour analyser l'évolution de la création d'entreprises au fil du temps. Affichez le nombre d'entreprises fondées chaque année, trié par année. Puis sauvegarder le résultat dans un fichier `tache2_3.csv`

# %%
data = db.companies.aggregate([
    {"$group": {"_id": "$founded_year", "nombreEntreprises": { "$sum": 1 }}},
    {"$sort": {"_id": -1}},
])
df = pd.DataFrame(data)
df = df.rename(columns={"_id": "founded_year"})
df.to_csv('tache2_3.csv')

# %% [markdown]
# ### **Étape 3 : Visualisation des données**
#
# #### Tâche 3.1 : Graphique de la répartition des entreprises par secteur
# - Utilisez un outil de visualisation tel que **Matplotlib** pour créer un graphique à barres représentant la répartition des entreprises par secteur.
# - Nous allons ajouter un **widget de sélection** permettant à l'utilisateur de filtrer les données en fonction du secteur d'activité qu'il souhaite visualiser.Le widget de type "dropdown" permet à l'utilisateur de choisir un secteur d'activité.
# - Le graphique à barres est mis à jour en fonction du secteur sélectionné.

# %%
data = db.companies.aggregate([
    {"$match": {"category_code": {"$ne": None }}},
    {"$group": {"_id": "$category_code", "nombreEntreprises": {"$sum": 1}}},
    {"$sort": {"nombreEntreprises": -1}},
])


names = df["_id"]


def update_plot(selected_sector):
    filtered_data = df[df["_id"] == selected_sector]

    plt.bar(filtered_data["_id"], filtered_data["nombreEntreprises"])
    plt.suptitle('Top 5 Categories of Companies')
    plt.xlabel('Categories')
    plt.ylabel('Number of Companies')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()


sector_widget = widgets.Dropdown(options=names, description='Secteur:')

interact(update_plot, selected_sector=sector_widget);
# Out:
# interactive(children=(Dropdown(description='Secteur:', options=('web', 'software', 'games_video', 'mobile', 'a…

# %% [markdown]
# #### Tâche 3.2 : Graphique de la répartition géographique
# - Créez un diagramme circulaire (pie chart) pour visualiser la répartition des entreprises par pays en affichant les 5 pays les plus représentés.
# - Ajoutons un **widget multi-sélection** pour permettre à l'utilisateur de sélectionner plusieurs pays et d'afficher un diagramme circulaire (pie chart) montrant la répartition des entreprises dans ces pays. L'utilisateur peut sélectionner plusieurs pays à l'aide d'un widget "SelectMultiple".
# - Le diagramme circulaire est mis à jour pour afficher la répartition des entreprises dans les pays sélectionnés.

# %% [markdown]
# #### Tâche 3.3 : Graphique de l’évolution des entreprises par année
# - Créez un graphique linéaire (line chart) montrant l’évolution du nombre d’entreprises créées chaque année.
# - Ajoutons un **slider interactif** pour permettre à l'utilisateur de filtrer la plage d'années qu'il souhaite visualiser dans le graphique linéaire montrant l'évolution du nombre d'entreprises créées. Le slider permet de définir une plage d'années.
# - Le graphique linéaire est mis à jour en fonction de la plage d'années sélectionnée, montrant l’évolution du nombre d’entreprises créées sur cette période.

# %% [markdown]
# ### **Livrables** :
# 1. Code source des requêtes MongoDB utilisées pour l'extraction et la transformation des données dans un fichier zip incluant : notebook Num-DA_TP2_420-514.ipynb, les fichiers csv créés.
# 2. Les graphiques générés pour visualiser les résultats des analyses.
# 3. Un rapport expliquant les résultats de l'analyse, incluant une interprétation des graphiques.
#
# ---
#
# ### **Évaluation** :
# Le TP sera noté sur la base des critères suivants :
# - Capacité à extraire les bonnes données de MongoDB (30%).
# - Capacité à transformer et structurer les données pour obtenir des insights pertinents (30%).
# - Qualité des visualisations et interprétation des résultats (30%).
# - Clarté et présentation du rapport final (10%).
#
# ---
#
# ### **Instructions supplémentaires** :
# - Vous pouvez utiliser PyMongo pour interagir avec MongoDB à partir de Python.
# - Les visualisations doivent être produites avec **Matplotlib**, **Widgets** et **interact** en Python.
# - Le respect des bonnes pratiques de nommage et de documentation de votre code sera pris en compte.
#
# ---
#
# ### **Ressources** :
# - [Documentation MongoDB](https://docs.mongodb.com/manual/)
# - [PyMongo - MongoDB pour Python](https://pymongo.readthedocs.io/en/stable/)
# - [Matplotlib](https://matplotlib.org/stable/users/index.html)
# - [ineteract](https://ipywidgets.readthedocs.io/en/8.1.5/examples/Using%20Interact.html)
# - [Widgets](https://ipywidgets.readthedocs.io/en/stable/examples/Widget%20List.html)
